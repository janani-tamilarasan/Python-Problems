# %% [markdown]
# <a href="https://colab.research.google.com/github/janani-tamilarasan/Python-Problems/blob/main/1_d_word_guessing_game.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##  Word Guessing Game (Mini Hangman)
#
# Objective:
#
# Create a word-guessing game where the player tries to guess the letters of a hidden word.
#
# This will test your:
# ●	Loops
#
# ●	Conditional logic
#
# ●	String manipulation
#
# ●	Exception handling
#
# ●	Logical thinking
#
# **Instructions**:
#
# 1.	Create a list of random words (like “python”, “machine”, “learning”, “bridge”).
#
# 2.	Randomly select one word for the game.
#
# 3.	Show the word as blanks (_ _ _ _) and let the player guess one letter at a time.
#
# 4.	Keep track of wrong guesses (max 6 attempts).
#
# 5.	End the game when the player either guesses the full word or uses all chances.

# %%
import random

words = ["python", "machine", "learning", "bridge"]

word = random.choice(words)

hidden_word = ["_"] * len(word)

attempts = 6
guessed_letters = []

print("Welcome to the Word Guessing Game!")

while attempts > 0 and "_" in hidden_word:

    print("Attempts left:", attempts)
    print("Guessed letters:", guessed_letters)

    try:
        guess = input("Enter a letter: ").lower()

        if len(guess) != 1 or not guess.isalpha():
            print("Please enter a single alphabet.")
            continue

        if guess in guessed_letters:
            print("You already guessed that letter.")
            continue

        guessed_letters.append(guess)

        if guess in word:

            for i in range(len(word)):
                if word[i] == guess:
                    hidden_word[i] = guess

            print("Correct!")

        else:
            attempts -= 1
            print("Wrong guess!")

    except Exception as e:
        print("Error:", e)

if "_" not in hidden_word:
    print("\nCongratulations! You guessed the word:", word)
else:
    print("\nGame Over!")
    print("The word was:", word)
# Out:
# Welcome to the Word Guessing Game!
#
# Word: _ _ _ _ _ _ _ _
# Attempts left: 6
# Guessed letters: []
# Enter a letter: p
# Wrong guess!
#
# Word: _ _ _ _ _ _ _ _
# Attempts left: 5
# Guessed letters: ['p']
# Enter a letter: y
# Wrong guess!
#
# Word: _ _ _ _ _ _ _ _
# Attempts left: 4
# Guessed letters: ['p', 'y']
# Enter a letter: t
# Wrong guess!
#
# Word: _ _ _ _ _ _ _ _
# Attempts left: 3
# Guessed letters: ['p', 'y', 't']
# Enter a letter: t
# You already guessed that letter.
#
# Word: _ _ _ _ _ _ _ _
# Attempts left: 3
# Guessed letters: ['p', 'y', 't']
# Enter a letter: fdsaf
# Please enter a single alphabet.
#
# Word: _ _ _ _ _ _ _ _
# Attempts left: 3
# Guessed letters: ['p', 'y', 't']
# Enter a letter: dfsa
# Please enter a single alphabet.
#
# Word: _ _ _ _ _ _ _ _
# Attempts left: 3
# Guessed letters: ['p', 'y', 't']
# Enter a letter: a
# Correct!
#
# Word: _ _ a _ _ _ _ _
# Attempts left: 3
# Guessed letters: ['p', 'y', 't', 'a']
# Enter a letter: h
# Wrong guess!
#
# Word: _ _ a _ _ _ _ _
# Attempts left: 2
# Guessed letters: ['p', 'y', 't', 'a', 'h']
# Enter a letter: o
# Wrong guess!
#
# Word: _ _ a _ _ _ _ _
# Attempts left: 1
# Guessed letters: ['p', 'y', 't', 'a', 'h', 'o']
# Enter a letter: n
# Correct!
#
# Word: _ _ a _ n _ n _
# Attempts left: 1
# Guessed letters: ['p', 'y', 't', 'a', 'h', 'o', 'n']
# Enter a letter: s
# Wrong guess!
#
# Game Over!
# The word was: learning
